# %%
#analyze bank churning
import pandas as pd

# %%
data=pd.read_csv("C:\\Bank_churn_modelling - Copy.csv")
data.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
data[['Age','Exited']].corr()
# Out:
#              Age    Exited
# Age     1.000000  0.285323
# Exited  0.285323  1.000000

# %%
x=lambda temp : 0 if temp=='0' else 1
data['Gender']=data['Gender'].apply(x)

# %%
data.corr()
# Out:
#                  RowNumber  CustomerId  CreditScore  Gender       Age  \
# RowNumber         1.000000    0.004202     0.005840     NaN  0.000783
# CustomerId        0.004202    1.000000     0.005308     NaN  0.009497
# CreditScore       0.005840    0.005308     1.000000     NaN -0.003965
# Gender                 NaN         NaN          NaN     NaN       NaN
# Age               0.000783    0.009497    -0.003965     NaN  1.000000
# Tenure           -0.006495   -0.014883     0.000842     NaN -0.009997
# Balance          -0.009067   -0.012419     0.006268     NaN  0.028308
# NumOfProducts     0.007246    0.016972     0.012238     NaN -0.030680
# HasCrCard         0.000599   -0.014025    -0.005458     NaN -0.011721
# IsActiveMember    0.012044    0.001665     0.025651     NaN  0.085472
# EstimatedSalary  -0.005988    0.015271    -0.001384     NaN -0.007201
# Exited           -0.016571   -0.006248    -0.027094     NaN  0.285323
#
# ...

# %%
df = pd.DataFrame(data, columns=["RowNumber", "CustomerId", "CreditScore","Gender","Age","Tenure","Balance","NumOfProducts","HasCrCard","IsActiveMember","EstimatedSalary","Exited"])
df.plot(x="Exited", y="Age",
        kind="barh", figsize=(10, 10))
# Out:
# <AxesSubplot:ylabel='Exited'>

# %%
df.plot(x="Exited", y="Age",
        kind="density", figsize=(10, 10))
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
g=data.groupby('Age')
dic={}
for name, dataframe in g:
    int tot=0

# %%
out=pd.crosstab(data['Age'],data['Exited'])#lets us compare and contrast based off columns
print(type(out))

# %%
display((out[0]/(out[0]+out[1])).to_string())#to do this we need margins
